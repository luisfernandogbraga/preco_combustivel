# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('anp.csv')
display(df)
# Out:
#         Regiao - Sigla Estado - Sigla   Municipio  \
# 0                    N             AC  RIO BRANCO
# 1                    N             AC  RIO BRANCO
# 2                    N             AC  RIO BRANCO
# 3                    N             AC  RIO BRANCO
# 4                    N             AC  RIO BRANCO
# ...                ...            ...         ...
# 1811497              N             AP     SANTANA
# 1811498              N             AP     SANTANA
# 1811499             NE             PI    PARNAIBA
# 1811500             NE             PI    PARNAIBA
# 1811501             NE             PI    PARNAIBA
#
#                                     Revenda  \
# 0                 AUTO POSTO AMAPA - EIRELI
# 1                 AUTO POSTO AMAPA - EIRELI
# 2                 AUTO POSTO AMAPA - EIRELI
# 3                 AUTO POSTO AMAPA - EIRELI
# 4                 AUTO POSTO AMAPA - EIRELI
# ...                                     ...
# 1811497  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1811498  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1811499           MAXXI DELTA PETROLEO LTDA
# 1811500           MAXXI DELTA PETROLEO LTDA
# 1811501           MAXXI DELTA PETROLEO LTDA
#
#                                      Nome da Rua         Bairro  \
# 0                               VIA CHICO MENDES          AREAL
# 1                               VIA CHICO MENDES          AREAL
# 2                               VIA CHICO MENDES          AREAL
# 3                               VIA CHICO MENDES          AREAL
# 4                               VIA CHICO MENDES          AREAL
# ...                                          ...            ...
# 1811497  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1811498  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1811499        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1811500        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1811501        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
#
#                     Produto Data da Coleta  Valor de Venda       Bandeira
# 0                  GASOLINA     03/01/2022            6.99  VIBRA ENERGIA
# 1                    ETANOL     03/01/2022            5.99  VIBRA ENERGIA
# 2                    DIESEL     03/01/2022            6.09  VIBRA ENERGIA
# 3        GASOLINA ADITIVADA     03/01/2022            7.05  VIBRA ENERGIA
# 4                DIESEL S10     03/01/2022            6.12  VIBRA ENERGIA
# ...                     ...            ...             ...            ...
# 1811497              DIESEL     28/12/2023            6.44       IPIRANGA
# 1811498          DIESEL S10     28/12/2023            6.49       IPIRANGA
# 1811499            GASOLINA     27/12/2023            5.20         BRANCA
# 1811500  GASOLINA ADITIVADA     27/12/2023            5.20         BRANCA
# 1811501              ETANOL     27/12/2023            3.99         BRANCA
#
# [1811502 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1811502 entries, 0 to 1811501
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Regiao - Sigla  object
#  1   Estado - Sigla  object
#  2   Municipio       object
#  3   Revenda         object
#  4   Nome da Rua     object
#  5   Bairro          object
#  6   Produto         object
#  7   Data da Coleta  object
#  8   Valor de Venda  float64
#  9   Bandeira        object
# dtypes: float64(1), object(9)
# memory usage: 138.2+ MB

# %%
df['Data da Coleta'] = pd.to_datetime(df['Data da Coleta'], format="%d/%m/%Y")

# %%
df.describe()
# Out:
#                       Data da Coleta  Valor de Venda
# count                        1811502    1.811502e+06
# mean   2022-12-23 11:14:08.986973440    5.710820e+00
# min              2022-01-03 00:00:00    2.390000e+00
# 25%              2022-06-07 00:00:00    4.990000e+00
# 50%              2022-12-29 00:00:00    5.690000e+00
# 75%              2023-07-10 00:00:00    6.490000e+00
# max              2023-12-29 00:00:00    9.790000e+00
# std                              NaN    1.094552e+00

# %%
df.isnull().sum()
# Out:
# Regiao - Sigla       0
# Estado - Sigla       0
# Municipio            0
# Revenda              0
# Nome da Rua          0
# Bairro            4016
# Produto              0
# Data da Coleta       0
# Valor de Venda       0
# Bandeira             0
# dtype: int64

# %%
df= df.dropna()
display(df)
# Out:
#         Regiao - Sigla Estado - Sigla   Municipio  \
# 0                    N             AC  RIO BRANCO
# 1                    N             AC  RIO BRANCO
# 2                    N             AC  RIO BRANCO
# 3                    N             AC  RIO BRANCO
# 4                    N             AC  RIO BRANCO
# ...                ...            ...         ...
# 1811497              N             AP     SANTANA
# 1811498              N             AP     SANTANA
# 1811499             NE             PI    PARNAIBA
# 1811500             NE             PI    PARNAIBA
# 1811501             NE             PI    PARNAIBA
#
#                                     Revenda  \
# 0                 AUTO POSTO AMAPA - EIRELI
# 1                 AUTO POSTO AMAPA - EIRELI
# 2                 AUTO POSTO AMAPA - EIRELI
# 3                 AUTO POSTO AMAPA - EIRELI
# 4                 AUTO POSTO AMAPA - EIRELI
# ...                                     ...
# 1811497  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1811498  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1811499           MAXXI DELTA PETROLEO LTDA
# 1811500           MAXXI DELTA PETROLEO LTDA
# 1811501           MAXXI DELTA PETROLEO LTDA
#
#                                      Nome da Rua         Bairro  \
# 0                               VIA CHICO MENDES          AREAL
# 1                               VIA CHICO MENDES          AREAL
# 2                               VIA CHICO MENDES          AREAL
# 3                               VIA CHICO MENDES          AREAL
# 4                               VIA CHICO MENDES          AREAL
# ...                                          ...            ...
# 1811497  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1811498  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1811499        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1811500        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1811501        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
#
#                     Produto Data da Coleta  Valor de Venda       Bandeira
# 0                  GASOLINA     2022-01-03            6.99  VIBRA ENERGIA
# 1                    ETANOL     2022-01-03            5.99  VIBRA ENERGIA
# 2                    DIESEL     2022-01-03            6.09  VIBRA ENERGIA
# 3        GASOLINA ADITIVADA     2022-01-03            7.05  VIBRA ENERGIA
# 4                DIESEL S10     2022-01-03            6.12  VIBRA ENERGIA
# ...                     ...            ...             ...            ...
# 1811497              DIESEL     2023-12-28            6.44       IPIRANGA
# 1811498          DIESEL S10     2023-12-28            6.49       IPIRANGA
# 1811499            GASOLINA     2023-12-27            5.20         BRANCA
# 1811500  GASOLINA ADITIVADA     2023-12-27            5.20         BRANCA
# 1811501              ETANOL     2023-12-27            3.99         BRANCA
#
# [1807486 rows x 10 columns]

# %%
for coluna in df.columns:
    print(f'Valores únicos em {coluna}: {df[coluna].unique()}')
# Out:
# Valores únicos em Regiao - Sigla: ['N' 'NE' 'SE' 'CO' 'S']
# Valores únicos em Estado - Sigla: ['AC' 'AL' 'AM' 'BA' 'CE' 'ES' 'TO' 'GO' 'MG' 'MS' 'MT' 'PA' 'PB' 'PE'
#  'PI' 'PR' 'RJ' 'RS' 'SE' 'SP' 'RN' 'SC' 'AP' 'DF' 'RO' 'MA' 'RR']
# Valores únicos em Municipio: ['RIO BRANCO' 'ARAPIRACA' 'ITACOATIARA' 'ILHEUS' 'SALVADOR' 'ITAPIPOCA'
#  'MARACANAU' 'ARACRUZ' 'LINHARES' 'SERRA' 'ARAGUAINA' 'CALDAS NOVAS'
#  'ITUMBIARA' 'RIO VERDE' 'TRINDADE' 'CONSELHEIRO LAFAIETE' 'CONTAGEM'
#  'DIVINOPOLIS' 'JOAO MONLEVADE' 'JUIZ DE FORA' 'MONTES CLAROS'
#  'PARA DE MINAS' 'PATROCINIO' 'DOURADOS' 'CACERES' 'CUIABA' 'ALTAMIRA'
#  'BELEM' 'BAYEUX' 'CAMPINA GRANDE' 'BELO JARDIM' 'GOIANA'
#  'SANTA CRUZ DO CAPIBARIBE' 'TERESINA' 'CASCAVEL' 'FOZ DO IGUACU' 'TOLEDO'
#  'UMUARAMA' 'ANGRA DOS REIS' 'ITAPERUNA' 'NITEROI' 'SAO GONCALO'
#  'TERESOPOLIS' 'CAXIAS DO SUL' 'LAJEADO' 'SANTA ROSA' 'SANTO ANGELO'
#  'VACARIA' 'ARACAJU' 'CARAGUATATUBA' 'CATANDUVA' 'VOTUPORANGA' 'DIADEMA'
#  'EMBU DAS ARTES' 'HORTOLANDIA' 'IBITINGA' 'MARILIA' 'MOCOCA'
#  'PRESIDENTE VENCESLAU' 'SANTO ANDRE' 'SANTOS' 'SAO CAETANO DO SUL'
#  'SAO JOAO DA BOA VISTA' 'SAO VICENTE' 'TABOAO DA SERRA' 'MACEIO' 'TEFE'
#  'BRUMADO' 'GUANAMBI' 'VITORIA DA CONQUISTA' 'FORMOSA' 'GURUPI' 'JATAI'
#  'MINEIROS' 'MANHUACU' 'MURIAE' 'TEOFILO OTONI' 'UBA' 'UBERABA' 'VICOSA'
#  'SANTAREM' 'JOAO PESSOA' 'IGARASSU' 'MARINGA' 'PARANAGUA' 'BARRA MANSA'
#  'NOVA FRIBURGO' 'MOSSORO' 'GUAIBA' 'IJUI' 'BALNEARIO CAMBORIU' 'ITAJAI'
#  'ARARAS' 'BEBEDOURO' 'CAMPINAS' 'FRANCA' 'INDAIATUBA' 'LEME' 'LINS'
#  'PARAGUACU PAULISTA' 'PIRASSUNUNGA' 'PORTO FERREIRA' 'PRAIA GRANDE'
#  'PRESIDENTE PRUDENTE' 'SAO BERNARDO DO CAMPO' 'SAO CARLOS' 'SUMARE'
#  'AGUAS LINDAS DE GOIAS' 'PELOTAS' 'VALPARAISO DE GOIAS' 'OURINHOS'
#  'ITABUNA' 'PAULINIA' 'COLOMBO' 'SAO FRANCISCO DE ITABAPOANA'
#  'DELMIRO GOUVEIA' 'MACAPA' 'CRATEUS' 'QUIXADA' 'BRASILIA' 'GUARAPARI'
#  'SAO MATEUS' 'VITORIA' 'APARECIDA DE GOIANIA' 'GOIANIA' 'MORRINHOS'
#  'PALMAS' 'ALFENAS' 'BETIM' 'IPATINGA' 'JOAO PINHEIRO' 'OLIVEIRA'
#  'POCOS DE CALDAS' 'SAO SEBASTIAO DO PARAISO' 'SETE LAGOAS' 'PONTA PORA'
#  'TRES LAGOAS' 'ALTA FLORESTA' 'SINOP' 'CAMETA' 'CONCEICAO DO ARAGUAIA'
#  'MARABA' 'SOUSA' 'ARARIPINA' 'GARANHUNS' 'JABOATAO DOS GUARARAPES'
#  'PAULISTA' 'PETROLINA' 'CAMPO MOURAO' 'CORNELIO PROCOPIO'
#  'FRANCISCO BELTRAO' 'PINHAIS' 'NOVA IGUACU' 'BELFORD ROXO'
#  'RIO DE JANEIRO' 'SAO JOAO DE MERITI' 'SAQUAREMA' 'VOLTA REDONDA' 'NATAL'
#  'CACOAL' 'PIMENTA BUENO' 'PORTO VELHO' 'PASSO FUNDO' 'BLUMENAU'
#  'NOSSA SENHORA DO SOCORRO' 'ATIBAIA' 'BAURU' 'COTIA' 'CRUZEIRO' 'CUBATAO'
#  'DRACENA' 'GUARULHOS' 'ITANHAEM' 'JABOTICABAL' 'JALES' 'JAU'
#  'JOSE BONIFACIO' 'MIRASSOL' 'MOGI DAS CRUZES' 'MONTE ALTO' 'PIRACICABA'
#  'POA' 'RIO CLARO' 'SAO PAULO' 'SUZANO' 'TAUBATE' 'MANAUS' 'CAMACARI'
#  'FEIRA DE SANTANA' 'JUAZEIRO' 'LAURO DE FREITAS' 'PAULO AFONSO'
#  'SIMOES FILHO' 'FORTALEZA' 'IMPERATRIZ' 'SAO JOSE DE RIBAMAR'
#  'BELO HORIZONTE' 'CAMPO BELO' 'LAJEDO' 'PARNAIBA' 'CAMBE' 'CURITIBA'
#  'SAO JOSE DOS PINHAIS' 'VALENCA' 'PORTO ALEGRE' 'BIGUACU' 'CACADOR'
#  'JOINVILLE' 'MAFRA' 'SAO JOSE' 'ITABAIANA' 'ARACATUBA' 'BARRETOS'
#  'CARAPICUIBA' 'GUARUJA' 'ITAPEVA' 'ITAPOLIS' 'LIMEIRA' 'LORENA' 'OSASCO'
#  'TATUI' 'TUPA' 'UBATUBA' 'SANTA MARIA' 'VILHENA' 'PARAUAPEBAS'
#  'ADAMANTINA' 'EUNAPOLIS' 'BOA VISTA' 'CRUZ ALTA' 'BARREIRAS' 'IRECE'
#  'JUAZEIRO DO NORTE' 'LIMOEIRO DO NORTE' 'VILA VELHA' 'ANAPOLIS'
#  'SAO LUIS' 'BARBACENA' 'FORMIGA' 'ITAUNA' 'JANUARIA' 'PARACATU'
#  'PATOS DE MINAS' 'POUSO ALEGRE' 'SAO JOAO DEL REI' 'UBERLANDIA'
#  'CAMPO GRANDE' 'ALENQUER' 'ANANINDEUA' 'CABEDELO'
#  'CABO DE SANTO AGOSTINHO' 'CARUARU' 'RECIFE' 'SERRA TALHADA' 'ARAPONGAS'
#  'CIANORTE' 'GUARAPUAVA' 'LONDRINA' 'PARANAVAI' 'UNIAO DA VITORIA'
#  'RIO BONITO' 'NILOPOLIS' 'PARNAMIRIM' 'ALVORADA' 'BAGE'
#  'CACHOEIRA DO SUL' 'SAPIRANGA' 'VIAMAO' 'ARARANGUA' 'BRUSQUE' 'CRICIUMA'
#  'TUBARAO' 'ARARAQUARA' 'CACAPAVA' 'ITAPETININGA' 'RIBEIRAO PRETO'
#  "SANTA BARBARA D'OESTE" 'SANTA CRUZ DO RIO PARDO' 'SAO JOSE DO RIO PRETO'
#  'SERTAOZINHO' 'SOROCABA' 'VALINHOS' 'CAUCAIA' 'IGUATU' 'CARIACICA'
#  'ARAGUARI' 'CORONEL FABRICIANO' 'MONTE CARMELO' 'VARZEA GRANDE'
#  'APUCARANA' 'CASTRO' 'PETROPOLIS' 'ALEGRETE' 'CACHOEIRINHA' 'ERECHIM'
#  'GRAVATAI' 'OSORIO' 'SAO GABRIEL' 'LAGUNA' 'AMERICANA' 'ASSIS' 'BIRIGUI'
#  'BARUERI' 'GARCA' 'ITAPECERICA DA SERRA' 'ITAQUAQUECETUBA' 'ITU'
#  'JACAREI' 'SAO JOSE DOS CAMPOS' 'SAO ROQUE' 'VINHEDO' 'VOTORANTIM'
#  'CHAPECO' 'LUZIANIA' 'CRUZEIRO DO SUL' 'CRATO' 'GOVERNADOR VALADARES'
#  'LAVRAS' 'PASSOS' 'MOGI GUACU' 'TIMOTEO' 'OLINDA' 'ARARUAMA' 'RESENDE'
#  'CANOAS' 'NOVO HAMBURGO' 'SANTA CRUZ DO SUL' 'SAO LEOPOLDO' 'LAGES'
#  'XANXERE' 'AMPARO' 'AVARE' 'COSMOPOLIS' 'GUARATINGUETA' 'JUNDIAI' 'MATAO'
#  'MAUA' 'MOGI MIRIM' 'RIBEIRAO PIRES' 'BOM DESPACHO' 'UNAI'
#  'DUQUE DE CAXIAS' 'BENTO GONCALVES' 'ESTEIO' 'SAO LUIZ GONZAGA'
#  'SAPUCAIA DO SUL' 'FLORIANOPOLIS' 'BRAGANCA PAULISTA' 'ITAPIRA' 'ITATIBA'
#  'PINDAMONHANGABA' 'VARZEA PAULISTA' 'CAMPOS DOS GOYTACAZES' 'JEQUIE'
#  'PALHOCA' 'GUAXUPE' 'ABAETETUBA' 'CASTANHAL' 'TORRES' 'OLIMPIA' 'ARAXA'
#  'CORUMBA' 'SORRISO' 'URUGUAIANA' 'VIDEIRA' 'BOTUCATU' 'RIO GRANDE'
#  'PALMEIRA DOS INDIOS' 'BRAGANCA' 'PONTA GROSSA' 'OURO PRETO' 'VARGINHA'
#  'SALTO' 'SERRINHA' 'ITAITUBA' 'ITAGUAI' 'CONCORDIA'
#  'CACHOEIRO DE ITAPEMIRIM' 'TRES CORACOES' 'RONDONOPOLIS' 'REDENCAO'
#  'PARAGOMINAS' 'VITORIA DE SANTO ANTAO' 'CAICO' 'CAETITE' 'PORTO NACIONAL'
#  'SANTO ANTONIO DA PLATINA' 'COLATINA' 'XINGUARA' 'PIRIPIRI' 'ITUIUTABA'
#  'COXIM' 'BARRA DO CORDA' 'SANTA INES' 'SANTANA DO LIVRAMENTO' 'POCOES'
#  'CATALAO' 'ITAJUBA' 'FRUTAL' 'RIO LARGO' 'ITABIRA' 'JARAGUA DO SUL'
#  'TRES RIOS' 'CABO FRIO' 'NOVA ANDRADINA' 'PORANGATU' 'PICOS' 'PARINTINS'
#  'ASSIS CHATEAUBRIAND' 'BALSAS' 'LAGARTO' 'SABARA'
#  'MARECHAL CANDIDO RONDON' 'GOIATUBA' 'JI-PARANA' 'PATO BRANCO' 'PINHEIRO'
#  'CAMPO LARGO' 'SOBRAL' 'MESQUITA' 'GRAMADO' 'MANACAPURU' 'ITABORAI'
#  'JAPARATUBA' 'MACAE' 'MARICA' 'CURVELO' 'PATOS' 'BARRA DO PIRAI'
#  'JANAUBA' 'LEOPOLDINA' 'CODO' 'ICO' 'SANTO ANTONIO DE PADUA' 'CAXIAS'
#  'ALAGOINHAS' 'SANTO ANTONIO DE JESUS' 'PRESIDENTE DUTRA' 'CONGONHAS'
#  'ARIQUEMES' 'CARATINGA' 'BACABAL' 'ITAMARAJU' 'PARAISO DO TOCANTINS'
#  'PORTO SEGURO' 'JACOBINA' 'TEIXEIRA DE FREITAS' 'ACAILANDIA'
#  'SENHOR DO BONFIM' 'JAGUAQUARA' 'ARCOVERDE' 'SANTANA' 'NOVA LIMA'
#  'SALGUEIRO' 'CANINDE' 'ARAUCARIA' 'IPIRA' 'LIVRAMENTO DE NOSSA SENHORA'
#  'SAPUCAIA' 'MAGE' 'PORTO GRANDE' 'AMARANTE DO MARANHAO' 'VERA CRUZ']
# Valores únicos em Revenda: ['AUTO POSTO AMAPA - EIRELI' 'AUTO POSTO ACAUAN LTDA'
#  'AUTO POSTO CORRENTAO LTDA' ... 'AUTO POSTO SHOPPING CIDADE LTDA'
#  'POSTO DE SERVICOS A5 LTDA' 'AUTO POSTO MERGULHAO LTDA']
# Valores únicos em Nome da Rua: ['VIA CHICO MENDES' 'RODOVIA AC 40'
#  'RODOVIA BR-364 (RIO BRANCO-PORTO VELHO)' ... 'EST   DINORAH'
#  'RUA IMPERATRIZ TERESA CRISTINA' 'AV DOMINGOS JOSE DE ALMEIDA']
# Valores únicos em Bairro: ['AREAL' 'VILA ACRE' 'SANTA INES' ... 'JARDIM RODEIO'
#  'LOTEAMENTO DINORÁ ROSA' 'NUCLEO URBANO SANTANA']
# Valores únicos em Produto: ['GASOLINA' 'ETANOL' 'DIESEL' 'GASOLINA ADITIVADA' 'DIESEL S10' 'GNV']
# Valores únicos em Data da Coleta: <DatetimeArray>
# ['2022-01-03 00:00:00', '2022-01-04 00:00:00', '2022-01-05 00:00:00',
#  '2022-01-06 00:00:00', '2022-01-07 00:00:00', '2022-01-10 00:00:00',
#  '2022-01-11 00:00:00', '2022-01-12 00:00:00', '2022-01-13 00:00:00',
#  '2022-01-14 00:00:00',
#  ...
#  '2023-12-19 00:00:00', '2023-12-18 00:00:00', '2023-12-21 00:00:00',
#  '2023-12-20 00:00:00', '2023-12-22 00:00:00', '2023-12-28 00:00:00',
#  '2023-12-29 00:00:00', '2023-12-25 00:00:00', '2023-12-27 00:00:00',
#  '2023-12-26 00:00:00']
# Length: 513, dtype: datetime64[ns]
# Valores únicos em Valor de Venda: [6.99 5.99 6.09 ... 9.69 2.76 9.79]
# Valores únicos em Bandeira: ['VIBRA ENERGIA' 'BRANCA' 'SABBÁ' "ATEM' S" 'RAIZEN' 'IPIRANGA' 'ALESAT'
#  'SP' 'TAURUS' 'STANG' 'RODOIL' 'PETROX DISTRIBUIDORA' 'EQUADOR'
#  'MASUT DISTRIBUIDORA' 'RIO BRANCO' 'FAN' 'CHARRUA' 'RAIZEN MIME'
#  'CIAPETRO' 'PETROBAHIA' 'IDAZA' 'AMERICANOIL' 'SMALL'
#  'SETTA DISTRIBUIDORA' 'LARCO' 'FEDERAL ENERGIA' 'WATT' 'TOTALENERGIES'
#  'TEMAPE' 'ATLÂNTICA' 'SIMARELLI' 'DISLUB' 'UNI' 'PETROSERRA' 'POTENCIAL'
#  'MAXSUL' 'DIBRAPE' 'RUFF C.J.' 'RZD DISTRIBUIDORA' 'ROYAL FIC'
#  'TDC DISTRIBUIDORA' 'MONTEPETRO' 'TORRAO' 'WALENDOWSKY'
#  'SUL COMBUSTÍVEIS' 'REJAILE' 'TOBRAS' 'PELIKANO' 'ESTRADA' 'PETRONAC'
#  'SUPERGASBRAS ENERGIA' 'LIQUIGÁS' 'FOGAS' 'NACIONAL GÁS BUTANO' 'BAHIANA'
#  'ULTRAGAZ' 'AMAZONGÁS' 'ON PETRO' 'D`MAIS' 'PETROBRASIL' 'AIR BP' 'VIBRA']

# %%
df.columns= df.columns.str.replace('Produto','Combustível')

# %%
display(df)
# Out:
#         Regiao - Sigla Estado - Sigla   Municipio  \
# 0                    N             AC  RIO BRANCO
# 1                    N             AC  RIO BRANCO
# 2                    N             AC  RIO BRANCO
# 3                    N             AC  RIO BRANCO
# 4                    N             AC  RIO BRANCO
# ...                ...            ...         ...
# 1811497              N             AP     SANTANA
# 1811498              N             AP     SANTANA
# 1811499             NE             PI    PARNAIBA
# 1811500             NE             PI    PARNAIBA
# 1811501             NE             PI    PARNAIBA
#
#                                     Revenda  \
# 0                 AUTO POSTO AMAPA - EIRELI
# 1                 AUTO POSTO AMAPA - EIRELI
# 2                 AUTO POSTO AMAPA - EIRELI
# 3                 AUTO POSTO AMAPA - EIRELI
# 4                 AUTO POSTO AMAPA - EIRELI
# ...                                     ...
# 1811497  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1811498  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1811499           MAXXI DELTA PETROLEO LTDA
# 1811500           MAXXI DELTA PETROLEO LTDA
# 1811501           MAXXI DELTA PETROLEO LTDA
#
#                                      Nome da Rua         Bairro  \
# 0                               VIA CHICO MENDES          AREAL
# 1                               VIA CHICO MENDES          AREAL
# 2                               VIA CHICO MENDES          AREAL
# 3                               VIA CHICO MENDES          AREAL
# 4                               VIA CHICO MENDES          AREAL
# ...                                          ...            ...
# 1811497  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1811498  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1811499        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1811500        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1811501        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
#
#                 Combustível Data da Coleta  Valor de Venda       Bandeira
# 0                  GASOLINA     2022-01-03            6.99  VIBRA ENERGIA
# 1                    ETANOL     2022-01-03            5.99  VIBRA ENERGIA
# 2                    DIESEL     2022-01-03            6.09  VIBRA ENERGIA
# 3        GASOLINA ADITIVADA     2022-01-03            7.05  VIBRA ENERGIA
# 4                DIESEL S10     2022-01-03            6.12  VIBRA ENERGIA
# ...                     ...            ...             ...            ...
# 1811497              DIESEL     2023-12-28            6.44       IPIRANGA
# 1811498          DIESEL S10     2023-12-28            6.49       IPIRANGA
# 1811499            GASOLINA     2023-12-27            5.20         BRANCA
# 1811500  GASOLINA ADITIVADA     2023-12-27            5.20         BRANCA
# 1811501              ETANOL     2023-12-27            3.99         BRANCA
#
# [1807486 rows x 10 columns]

# %%
plt.figure(figsize=(18, 6))
sns.countplot(x='Combustível', data=df, palette='viridis')
plt.grid(True,linestyle='--', alpha=0.7)
plt.title('Combustíveis mais usados')
plt.xlabel('Combustível')
plt.ylabel('Contagem')
plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_11744\2702775115.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Combustível', data=df, palette='viridis')

# %% [markdown]
# Gasolina de fato é o combustível mais usado, seguido pelo Etanol e o Gás Natural é o menos usado.

# %%
plt.figure(figsize=(18, 8))
sns.boxplot(x='Estado - Sigla', y='Valor de Venda', data=df, palette='Set2')
plt.grid(True,linestyle='--', alpha=0.7)
plt.title('Boxplot de Valores de Venda por Região')
plt.xlabel('Região')
plt.ylabel('Valor de Venda')
plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_11744\2544577309.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Estado - Sigla', y='Valor de Venda', data=df, palette='Set2')

# %%
plt.figure(figsize=(18, 8))
sns.barplot(x='Combustível', y='Valor de Venda', data=df, palette='viridis', ci=None)
plt.grid(True,linestyle='--', alpha=0.7)
plt.title('Média de Valor de Venda por Combustível')
plt.xlabel('Combustível')
plt.ylabel('Média de Valor de Venda')
plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_11744\2732361565.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Combustível', y='Valor de Venda', data=df, palette='viridis', ci=None)
# C:\Users\dulor\AppData\Local\Temp\ipykernel_11744\2732361565.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Combustível', y='Valor de Venda', data=df, palette='viridis', ci=None)

# %%
# Filtrar o DataFrame apenas para o produto 'Gasolina'
df_gasolina = df[df['Combustível'] == 'GASOLINA']

# Criar um gráfico de linha para a gasolina
plt.figure(figsize=(12, 6))
sns.lineplot(x='Data da Coleta', y='Valor de Venda', data=df_gasolina, ci=None)

# Adicionar título e rótulos aos eixos
plt.title('Histórico de Preços da Gasolina')
plt.xlabel('Data da Coleta')
plt.ylabel('Valor de Venda')

# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_11744\3909790203.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Data da Coleta', y='Valor de Venda', data=df_gasolina, ci=None)

# %%
# Solicitar o nome do produto usando input
combustivel = input('Digite o nome do produto para visualizar o histórico de preços: ')

# Filtrar o DataFrame para o produto escolhido
df_produto = df[df['Combustível'] == combustivel]

# Verificar se há dados para o produto
if df_produto.empty:
    print(f'Não há dados disponíveis para o produto "{combustivel}".')
else:
    # Calcular valores estatísticos
    media_valor = df_produto['Valor de Venda'].mean()
    max_valor = df_produto['Valor de Venda'].max()
    min_valor = df_produto['Valor de Venda'].min()

    # Criar um gráfico de linha para o produto escolhido
    plt.figure(figsize=(18, 6))
    sns.lineplot(x='Data da Coleta', y='Valor de Venda', data=df_produto, ci=None)
    
    plt.grid(True, linestyle='--', alpha=0.7)

    # Adicionar linhas para média, máximo e mínimo
    plt.axhline(y=media_valor, color='r', linestyle='--', label='Média')
    plt.text(df_produto['Data da Coleta'].max(), media_valor + 0.1, f'Média: {media_valor:.2f}', color='r', ha='left', va='center')

    # Adicionar título e rótulos aos eixos
    plt.title(f'Histórico de Preços do Combustível: {combustivel}')
    plt.xlabel('Data da Coleta')
    plt.ylabel('Valor de Venda')

     # Adicionar legenda
    plt.legend()

    # Mostrar o gráfico
    plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_11744\982213630.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Data da Coleta', y='Valor de Venda', data=df_produto, ci=None)
