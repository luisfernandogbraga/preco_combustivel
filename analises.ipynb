# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('anp.csv')

# %%
display(df)
# Out:
#         Regiao - Sigla Estado - Sigla   Municipio  \
# 0                NORTE             AC  RIO BRANCO
# 1                NORTE             AC  RIO BRANCO
# 2                NORTE             AC  RIO BRANCO
# 3                NORTE             AC  RIO BRANCO
# 4                NORTE             AC  RIO BRANCO
# ...                ...            ...         ...
# 1807481          NORTE             AP     SANTANA
# 1807482          NORTE             AP     SANTANA
# 1807483       NORDESTE             PI    PARNAIBA
# 1807484       NORDESTE             PI    PARNAIBA
# 1807485       NORDESTE             PI    PARNAIBA
#
#                                     Revenda  \
# 0                 AUTO POSTO AMAPA - EIRELI
# 1                 AUTO POSTO AMAPA - EIRELI
# 2                 AUTO POSTO AMAPA - EIRELI
# 3                 AUTO POSTO AMAPA - EIRELI
# 4                 AUTO POSTO AMAPA - EIRELI
# ...                                     ...
# 1807481  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1807482  POSTO DE COMBUSTIVEIS JARDINS LTDA
# 1807483           MAXXI DELTA PETROLEO LTDA
# 1807484           MAXXI DELTA PETROLEO LTDA
# 1807485           MAXXI DELTA PETROLEO LTDA
#
#                                      Nome da Rua         Bairro  \
# 0                               VIA CHICO MENDES          AREAL
# 1                               VIA CHICO MENDES          AREAL
# 2                               VIA CHICO MENDES          AREAL
# 3                               VIA CHICO MENDES          AREAL
# 4                               VIA CHICO MENDES          AREAL
# ...                                          ...            ...
# 1807481  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1807482  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ  VILA AMAZONAS
# 1807483        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1807484        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
# 1807485        AVENIDA DEPUTADO PINHEIRO MACHADO          PIAUÍ
#
#                 Combustível Data da Coleta  Valor de Venda       Bandeira
# 0                  GASOLINA     2022-01-03            6.99  VIBRA ENERGIA
# 1                    ETANOL     2022-01-03            5.99  VIBRA ENERGIA
# 2                    DIESEL     2022-01-03            6.09  VIBRA ENERGIA
# 3        GASOLINA ADITIVADA     2022-01-03            7.05  VIBRA ENERGIA
# 4                DIESEL S10     2022-01-03            6.12  VIBRA ENERGIA
# ...                     ...            ...             ...            ...
# 1807481              DIESEL     2023-12-28            6.44       IPIRANGA
# 1807482          DIESEL S10     2023-12-28            6.49       IPIRANGA
# 1807483            GASOLINA     2023-12-27            5.20         BRANCA
# 1807484  GASOLINA ADITIVADA     2023-12-27            5.20         BRANCA
# 1807485              ETANOL     2023-12-27            3.99         BRANCA
#
# [1807486 rows x 10 columns]

# %%
plt.figure(figsize=(18, 6))
sns.countplot(x='Combustível', data=df, palette='viridis')
plt.grid(True,linestyle='--', alpha=0.7)
plt.title('Combustíveis mais usados')
plt.xlabel('Combustível')
plt.ylabel('Contagem')
plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_18260\2702775115.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Combustível', data=df, palette='viridis')

# %%
plt.figure(figsize=(18, 8))
sns.barplot(x='Combustível', y='Valor de Venda', data=df, palette='viridis', ci=None)
plt.grid(True,linestyle='--', alpha=0.7)
plt.title('Média de Valor de Venda por Combustível')
plt.xlabel('Combustível')
plt.ylabel('Média de Valor de Venda')
plt.show()
# Out:
# C:\Users\dulor\AppData\Local\Temp\ipykernel_18260\2732361565.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Combustível', y='Valor de Venda', data=df, palette='viridis', ci=None)
# C:\Users\dulor\AppData\Local\Temp\ipykernel_18260\2732361565.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Combustível', y='Valor de Venda', data=df, palette='viridis', ci=None)

# %%
# Solicitar o nome do produto usando input
combustivel = input('Digite o nome do produto para visualizar o histórico de preços: ')

# Filtrar o DataFrame para o produto escolhido
df_produto = df[df['Combustível'] == combustivel]

# Verificar se há dados para o produto
if df_produto.empty:
    print(f'Não há dados disponíveis para o produto "{combustivel}".')
else:
    # Calcular valores estatísticos
    media_valor = df_produto['Valor de Venda'].mean()
    max_valor = df_produto['Valor de Venda'].max()
    min_valor = df_produto['Valor de Venda'].min()

    # Criar um gráfico de linha para o produto escolhido
    plt.figure(figsize=(18, 6))
    sns.lineplot(x='Data da Coleta', y='Valor de Venda', data=df_produto, ci=None)
    
    plt.grid(True, linestyle='--', alpha=0.7)

    # Adicionar linhas para média, máximo e mínimo
    plt.axhline(y=media_valor, color='r', linestyle='--', label='Média')
    plt.text(df_produto['Data da Coleta'].max(), media_valor + 0.1, f'Média: {media_valor:.2f}', color='r', ha='left', va='center')

    # Adicionar título e rótulos aos eixos
    plt.title(f'Histórico de Preços do Combustível: {combustivel}')
    plt.xlabel('Data da Coleta')
    plt.ylabel('Valor de Venda')

     # Adicionar legenda
    plt.legend()

    # Mostrar o gráfico
    plt.show()
# Out:
# Não há dados disponíveis para o produto "".

# %%
nome_combustivel= input('Digite o nome do produto para visualizar o histórico de preços: ')
df_combustivel = df[df['Combustível'] == nome_combustivel]

# Configurar o tamanho da figura
plt.figure(figsize=(18, 8))

# Criar o boxplot
sns.boxplot(x='Estado - Sigla', y='Valor de Venda', data=df_combustivel, palette='Set2')


plt.grid(True, linestyle='--', alpha=0.7)
plt.title(f'Boxplot de Valores de Venda de {nome_combustivel} por Região')
plt.xlabel('Região')
plt.ylabel('Valor de Venda')


plt.show()

# %%
# Solicitar ao usuário que digite o nome do produto
nome1_combustivel = input('Digite o nome do produto para visualizar o histórico de preços: ')

# Filtrar o DataFrame para o combustível selecionado
df_combustivel = df[df['Combustível'] == nome1_combustivel]

media_valor_por_estado = df_combustivel.groupby('Estado - Sigla')['Valor de Venda'].mean().sort_values()

# Configurar o tamanho da figura
plt.figure(figsize=(18, 8))

    # Criar o gráfico de barras
plt.bar(media_valor_por_estado.index, media_valor_por_estado.values, color=sns.color_palette('Set1'))

    # Adicionar detalhes ao gráfico
plt.grid(True, linestyle='--', alpha=0.7)
plt.title(f'Média de Valor de Venda de {nome1_combustivel} por Estado')
plt.xlabel('Estado')
plt.ylabel('Média de Valor de Venda')

   
plt.show()

# %%
# Solicitar ao usuário que digite o nome do produto
nome1_combustivel = input('Digite o nome do produto para visualizar o histórico de preços: ')

# Filtrar o DataFrame para o combustível selecionado
df_combustivel = df[df['Combustível'] == nome1_combustivel]

media_valor_por_estado = df_combustivel.groupby('Regiao - Sigla')['Valor de Venda'].mean().sort_values()

# Configurar o tamanho da figura
plt.figure(figsize=(18, 8))

    # Criar o gráfico de barras
plt.bar(media_valor_por_estado.index, media_valor_por_estado.values, color=sns.color_palette('Set1'))

    # Adicionar detalhes ao gráfico
plt.grid(True, linestyle='--', alpha=0.7)
plt.title(f'Média de Valor de Venda de {nome1_combustivel} por Região')
plt.xlabel('Região')
plt.ylabel('Média de Valor de Venda')

   
plt.show()

# %%
# REGIOES : SUDESTE , SUL , CENTRO OESTE , NORDESTE , NORTE 

# Solicitar ao usuário que digite o nome do produto
nome2_combustivel = input('Digite o nome do combustível para visualizar o histórico de preços: ')
nome_regiao = input('Digite o nome da região para filtrar os dados: ')

# Filtrar o DataFrame para o combustível e região selecionados
df_filtrado = df[(df['Combustível'] == nome2_combustivel) & (df['Regiao - Sigla'] == nome_regiao)]

media_valor_por_estado = df_filtrado.groupby('Estado - Sigla')['Valor de Venda'].mean().sort_values()

# Configurar o tamanho da figura
plt.figure(figsize=(18, 8))

    # Criar o gráfico de barras
plt.bar(media_valor_por_estado.index, media_valor_por_estado.values, color=sns.color_palette('Set1'))

    # Adicionar detalhes ao gráfico
plt.grid(True, linestyle='--', alpha=0.7)
plt.title(f'Média de Valor de Venda de {nome2_combustivel} na Região {nome_regiao}')
plt.xlabel('Estado')
plt.ylabel('Média de Valor de Venda')

    # Mostrar o gráfico
plt.show()

# %%
# Permitindo que o usuário escolha o município
nome3_municipio = input('Digite o nome do município para visualizar o histórico de preços: ')
df_municipio = df[df['Municipio'] == nome3_municipio]

# Simulando a entrada do usuário para o combustível
nome3_combustivel = input('Digite o nome do combustível para visualizar o histórico de preços: ')
df3_combustivel = df_municipio[df_municipio['Combustível'] == nome3_combustivel]

# Ordenando por Valor de Venda em ordem decrescente e pegando os 10 maiores
df_top_10 = df3_combustivel.sort_values(by='Valor de Venda', ascending=False).head(10)

# Plotando o gráfico
plt.figure(figsize=(18, 8))
plt.bar(df_top_10['Bairro'], df_top_10['Valor de Venda'], color=sns.color_palette('Set1'))
#plt.bar(df_top_10['Bairro'], df_top_10['Valor de Venda'], color='blue')
plt.xlabel('Bairro')
plt.ylabel('Valor de Venda')
plt.title(f'Os Maiores valores de venda de {nome3_combustivel} em {nome3_municipio} por Bairro')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Permitindo que o usuário escolha o município
nome4_municipio = input('Digite o nome do município para visualizar o histórico de preços: ')
df4_municipio = df[df['Municipio'] == nome4_municipio]

# Simulando a entrada do usuário para o combustível
nome4_combustivel = input('Digite o nome do produto para visualizar o histórico de preços: ')
df4_combustivel = df4_municipio[df4_municipio['Combustível'] == nome4_combustivel]

# Ordenando por Valor de Venda em ordem decrescente e pegando os 10 menores
df_ult_10 = df_combustivel.sort_values(by='Valor de Venda', ascending=False).tail(10)

# Plotando o gráfico
plt.figure(figsize=(18, 8))
plt.bar(df_ult_10['Bairro'], df_ult_10['Valor de Venda'], color=sns.color_palette('Set1'))
#plt.bar(df_ult_10['Bairro'], df_ult_10['Valor de Venda'], color='blue')
plt.xlabel('Bairro')
plt.ylabel('Valor de Venda')
plt.title(f'Os Bairros com menor valores de venda de {nome4_combustivel} em {nome4_municipio}')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Permitindo que o usuário escolha o município
nome5_municipio = input('Digite o nome do município para visualizar o histórico de preços: ')
df5_municipio = df[df['Municipio'] == nome5_municipio]

# Simulando a entrada do usuário para o combustível
nome5_combustivel = input('Digite o nome do produto para visualizar o histórico de preços: ')
df5_combustivel = df_municipio[df_municipio['Combustível'] == nome5_combustivel]

# Agrupando por bandeira e somando o total de vendas
df5_bandeira = df5_combustivel.groupby('Bandeira')['Valor de Venda'].sum().reset_index()

# Ordenando por valor de venda em ordem decrescente
df5_bandeira = df5_bandeira.sort_values(by='Valor de Venda', ascending=False)

# Plotando o gráfico de barras
plt.figure(figsize=(18, 8))
plt.bar(df5_bandeira['Bandeira'], df5_bandeira['Valor de Venda'], color=sns.color_palette('Set1'))
plt.xlabel('Bandeira')
plt.ylabel('Total de Vendas')
plt.title(f'Total de Vendas de {nome5_combustivel} por Bandeira em {nome5_municipio}')
plt.xticks(rotation=45, ha='right')
plt.show()
